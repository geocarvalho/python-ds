# %%
import pandas as pd

# %%
df = pd.read_csv('../pandas/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2017-12-13 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2017-12-13 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2017-12-13 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2017-12-13 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2017-12-13 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# # Filter a `DataFrame` based on a condition

# %%
df[df['Gender'] == 'Male'].head()
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2017-12-13 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2017-12-13 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2017-12-13 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2017-12-13 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2017-12-13 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
mask = df['Team'] == 'Finance'
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2017-12-13 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2017-12-13 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2017-12-13 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2017-12-13 07:13:00   41426   14.543
# 46      Bruce    Male 2009-11-28 2017-12-13 22:47:00  114796    6.796
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                True  Finance
# 14               True  Finance
# 46              False  Finance

# %%
df[df['Senior Management']].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2017-12-13 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2017-12-13 06:53:00   61933    4.170
# 3      Jerry    Male 2005-03-04 2017-12-13 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2017-12-13 16:47:00  101004    1.389
# 6       Ruby  Female 1987-08-17 2017-12-13 16:20:00   65476   10.012
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 6               True          Product

# %%
df[df['Team'] != 'Marketing'].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1     Thomas    Male 1996-03-31 2017-12-13 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2017-12-13 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2017-12-13 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2017-12-13 16:47:00  101004    1.389
# 5     Dennis    Male 1987-04-18 2017-12-13 01:35:00  115163   10.125
#
#    Senior Management             Team
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
df[df['Salary'] > 110000].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2017-12-13 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2017-12-13 13:00:00  138705    9.340
# 5      Dennis    Male 1987-04-18 2017-12-13 01:35:00  115163   10.125
# 9     Frances  Female 2002-08-08 2017-12-13 06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01 2017-12-13 01:08:00  112807   17.492
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# 5               False                 Legal
# 9                True  Business Development
# 12               True       Human Resources

# %%
df[df['Bonus %'] < 1.5].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2017-12-13 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2017-12-13 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2017-12-13 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2017-12-13 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2017-12-13 20:20:00  146651    1.451
#
#      Senior Management             Team
# 4                 True  Client Services
# 15               False          Product
# 58                True      Engineering
# 77                True        Marketing
# 175               True      Engineering
