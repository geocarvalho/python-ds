# %%
import pandas as pd
from pandas_datareader import data

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # The `.plot()` method

# %%
bb = data.DataReader(name='GOOG', data_source='yahoo', start='2004-01-01', end='2016-12-31')
bb.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
bb.plot()

# %%
bb.plot(y='Volume')

# %%
bb.plot(y=['High', 'Low'])
# Out:
# /home/george/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
bb[['High', 'Low']].plot()

# %% [markdown]
# # Modifying Aesthetics

# %%
bb.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
plt.style.available
# Out:
# ['seaborn-colorblind',
#  'seaborn-whitegrid',
#  'classic',
#  'seaborn-dark-palette',
#  'bmh',
#  'seaborn',
#  'seaborn-notebook',
#  '_classic_test',
#  'seaborn-poster',
#  'seaborn-muted',
#  'ggplot',
#  'seaborn-pastel',
#  'fivethirtyeight',
#  'grayscale',
#  'seaborn-dark',
#  'seaborn-bright',
#  'seaborn-white',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'seaborn-talk',
#  'dark_background',
#  'seaborn-paper',
#  'seaborn-deep']

# %%
bb.plot(y='Close')

# %%
plt.style.use('ggplot')
bb.plot(y='Close')

# %%
plt.style.use('fivethirtyeight')
bb.plot(y='Close')

# %%
plt.style.use('seaborn')
bb.plot(y='Close')

# %% [markdown]
# # Bar charts

# %%
 bb.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
def rank_performance(stock_price):
    if stock_price <= 200:
        return 'Poor'
    elif stock_price > 200 and stock_price <= 500:
        return 'Satisfactory'
    else:
        return 'Stellar'

# %%
bb['Close'].apply(rank_performance).value_counts()
# Out:
# Satisfactory    1716
# Stellar          797
# Poor             602
# Name: Close, dtype: int64

# %%
bb['Close'].apply(rank_performance).value_counts().plot(kind='bar')

# %%
bb['Close'].apply(rank_performance).value_counts().plot(kind='barh')

# %% [markdown]
# # Pie charts

# %%
bb.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
bb['Close'].mean()
# Out:
# 347.4202289595508

# %%
def rank_performance_2(stock_price):
    if stock_price >= 347.4202289595508:
        return 'Above average'
    else:
        return 'Below average'

# %%
bb['Close'].apply(rank_performance_2).value_counts().plot('pie', legend=True)

# %%
bb['Close'].apply(rank_performance).value_counts().plot(kind='pie', legend=True)

# %% [markdown]
# # Histograms

# %%
bb.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
def custom_round(stock_price):
    return int(stock_price / 100.0) * 100

# %%
bb['High'].apply(custom_round).value_counts().sort_index()
# Out:
# 0       159
# 100     419
# 200    1138
# 300     439
# 400     154
# 500     416
# 600     105
# 700     273
# 800      12
# Name: High, dtype: int64

# %%
bb['High'].apply(custom_round).nunique()
# Out:
# 9

# %%
bb['High'].apply(custom_round).plot(kind='hist', bins=9, legend=True)
